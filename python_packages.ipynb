# %% [markdown]
# <a href="https://colab.research.google.com/github/Yasmeen20110210/Final_Project/blob/main/python_packages.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
python_packages ="""pandas
numpy
seaborn
matplotlib
sklearn.preprocessing
numpy.linalg"""
with open("requirements.txt", "w") as f:
    f.write(python_packages)
print("requirement file is ready")
# Out:
# requirement file is ready
